# %% [markdown]
# # Data Wrangling -- Shark Attacks

# %% [markdown]
# ## 1. Import all necessary data and tools

# %%
import pandas as pd
import regex as re

# %%
shark_attacks = pd.read_csv('GSAF5.csv', engine = 'python')

# %% [markdown]
# ## 2. Understand the dataset

# %%
#Take a first peak at the date
shark_attacks.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# 3           Victoria                                 Thirteenth Beach
# 4           Victoria                                      Bells Beach
# 5  Western Australia                                          Bunbury
# 6            Florida                    Ponte Vedra, St. Johns County
# 7             Hawaii                                     Makaha, Oahu
# 8     North Province                                           Koumac
# 9     South Carolina  Kingston Plantation, Myrtle Beach, Horry County
#
#           Activity                    Name Sex   ...          Species   \
# 0          Surfing                    male    M  ...               NaN
# 1          Surfing          Chucky Luciano    M  ...               NaN
# 2          Surfing                    male    M  ...               NaN
# 3          Surfing         Rory Angiolella    M  ...               NaN
# 4          Surfing                    male    M  ...         2 m shark
# 5          Fishing  Occupant: Ben Stratton  NaN  ...               NaN
# 6           Wading                    male    M  ...    3' to 4' shark
# 7         Swimming                  female    F  ...  Tiger shark, 10?
# 8     Kite surfing            David Jewell    M  ...               NaN
# 9  Boogie boarding          Rylie Williams    F  ...               NaN
#
#         Investigator or Source                        pdf  \
# 0  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
# 5   West Australian, 9/15/2016      2016.09.15.R-boat.pdf
# 6          News4Jax, 9/11/2016  2016.09.11-PonteVedra.pdf
# 7    Hawaii News Now, 9/7/2016        2016.09.07-Oahu.pdf
# 8       TVANouvelles, 9/6/2016      2016.09.06-Jewell.pdf
# 9            C. Creswell, GSAF  2016.09.05.b-Williams.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.15.R
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.11
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.07
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.06
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.05.b
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
# 1  2016.09.18.b           5992         NaN         NaN
# 2  2016.09.18.a           5991         NaN         NaN
# 3    2016.09.17           5990         NaN         NaN
# 4    2016.09.15           5989         NaN         NaN
# 5  2016.09.15.R           5988         NaN         NaN
# 6    2016.09.11           5987         NaN         NaN
# 7    2016.09.07           5986         NaN         NaN
# 8    2016.09.06           5985         NaN         NaN
# 9  2016.09.05.b           5984         NaN         NaN
#
# [10 rows x 24 columns]

# %%
shark_attacks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark_attacks.size
# Out:
# 143808

# %%
#Look at the shape of the data (rows & columns)
shark_attacks.shape
# Out:
# (5992, 24)

# %% [markdown]
# ## 3. Data Wrangling

# %% [markdown]
# ### Handle missing values

# %%
#Look at missing values
shark_attacks.isna()
# Out:
#       Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0           False  False  False  False    False  False     False     False
# 1           False  False  False  False    False  False     False     False
# 2           False  False  False  False    False  False     False     False
# 3           False  False  False  False    False  False     False     False
# 4           False  False  False  False    False  False     False     False
# ...           ...    ...    ...    ...      ...    ...       ...       ...
# 5987        False  False  False  False    False  False     False     False
# 5988        False  False  False  False    False  False      True     False
# 5989        False  False  False  False    False  False     False     False
# 5990        False  False  False  False    False   True     False      True
# 5991        False  False  False  False    False  False     False     False
#
#        Name   Sex   ...  Species   Investigator or Source    pdf  \
# 0     False  False  ...      True                   False  False
# 1     False  False  ...      True                   False  False
# 2     False  False  ...      True                   False  False
# 3     False  False  ...      True                   False  False
# 4     False  False  ...     False                   False  False
# ...     ...    ...  ...       ...                     ...    ...
# 5987  False  False  ...      True                   False  False
# 5988  False  False  ...      True                   False  False
# 5989  False  False  ...      True                   False  False
# 5990  False  False  ...      True                   False  False
# 5991  False  False  ...      True                   False  False
#
#       href formula   href  Case Number.1  Case Number.2  original order  \
# 0            False  False          False          False           False
# 1            False  False          False          False           False
# 2            False  False          False          False           False
# 3            False  False          False          False           False
# 4            False  False          False          False           False
# ...            ...    ...            ...            ...             ...
# 5987         False  False          False          False           False
# 5988         False  False          False          False           False
# 5989         False  False          False          False           False
# 5990         False  False          False          False           False
# 5991         False  False          False          False           False
#
#       Unnamed: 22  Unnamed: 23
# 0            True         True
# 1            True         True
# 2            True         True
# 3            True         True
# 4            True         True
# ...           ...          ...
# 5987         True         True
# 5988         True         True
# 5989         True         True
# 5990         True         True
# 5991         True         True
#
# [5992 rows x 24 columns]

# %%
#Find out where missing values occur
shark_attacks.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Store missing values in a variable
missing_values = shark_attacks.isna().sum()

# %%
#Access missing values only 
missing_values.loc[missing_values.gt(0)]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Find out percentage of missing values per relevant column 
missing_values.loc[missing_values.gt(0)]/len(shark_attacks)
# Out:
# Country                   0.007176
# Area                      0.067089
# Location                  0.082777
# Activity                  0.087951
# Name                      0.033378
# Sex                       0.094626
# Age                       0.447430
# Injury                    0.004506
# Fatal (Y/N)               0.003171
# Time                      0.536215
# Species                   0.489653
# Investigator or Source    0.002503
# href formula              0.000167
# href                      0.000501
# Unnamed: 22               0.999833
# Unnamed: 23               0.999666
# dtype: float64

# %%
#Store the ratios in a variable
missing_values_ratios = missing_values.loc[missing_values.gt(0)]/len(shark_attacks)

# %%
#Identify all columns with percentages over 60%
missing_values_ratios.loc[missing_values_ratios.gt(0.6)].index
# Out:
# Index(['Unnamed: 22', 'Unnamed: 23'], dtype='object')

# %%
#Double check what is inside the columns 'Unnamed: 22' and 'Unnamed: 23'
missing_values['Unnamed: 22']
# Out:
# 5991

# %%
#Drop columsn with ratios over 60%, create a copy and store it in a variable
shark_attacks_copy = shark_attacks.drop(columns=missing_values_ratios.loc[missing_values_ratios.gt(0.6)].index).copy()

# %%
#Check the result
shark_attacks_copy.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# 3           Victoria                                 Thirteenth Beach
# 4           Victoria                                      Bells Beach
# 5  Western Australia                                          Bunbury
# 6            Florida                    Ponte Vedra, St. Johns County
# 7             Hawaii                                     Makaha, Oahu
# 8     North Province                                           Koumac
# 9     South Carolina  Kingston Plantation, Myrtle Beach, Horry County
#
#           Activity                    Name Sex   ... Fatal (Y/N)  \
# 0          Surfing                    male    M  ...           N
# 1          Surfing          Chucky Luciano    M  ...           N
# 2          Surfing                    male    M  ...           N
# 3          Surfing         Rory Angiolella    M  ...           N
# 4          Surfing                    male    M  ...           N
# 5          Fishing  Occupant: Ben Stratton  NaN  ...           N
# 6           Wading                    male    M  ...           N
# 7         Swimming                  female    F  ...           N
# 8     Kite surfing            David Jewell    M  ...           Y
# 9  Boogie boarding          Rylie Williams    F  ...           N
#
#              Time          Species        Investigator or Source  \
# 0           13h00               NaN  Orlando Sentinel, 9/19/2016
# 1           11h00               NaN  Orlando Sentinel, 9/19/2016
# 2           10h43               NaN  Orlando Sentinel, 9/19/2016
# 3             NaN               NaN           The Age, 9/18/2016
# 4             NaN         2 m shark           The Age, 9/16/2016
# 5             NaN               NaN   West Australian, 9/15/2016
# 6           15h15    3' to 4' shark          News4Jax, 9/11/2016
# 7           14h30  Tiger shark, 10?    Hawaii News Now, 9/7/2016
# 8           15h40               NaN       TVANouvelles, 9/6/2016
# 9  Late afternoon               NaN            C. Creswell, GSAF
#
#                          pdf  \
# 0       2016.09.18.c-NSB.pdf
# 1   2016.09.18.b-Luciano.pdf
# 2       2016.09.18.a-NSB.pdf
# 3  2016.09.17-Angiolella.pdf
# 4  2016.09.16-BellsBeach.pdf
# 5      2016.09.15.R-boat.pdf
# 6  2016.09.11-PonteVedra.pdf
# 7        2016.09.07-Oahu.pdf
# 8      2016.09.06-Jewell.pdf
# 9  2016.09.05.b-Williams.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.15.R
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.11
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.07
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.06
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.05.b
#
#   Case Number.2 original order
# 0  2016.09.18.c           5993
# 1  2016.09.18.b           5992
# 2  2016.09.18.a           5991
# 3    2016.09.17           5990
# 4    2016.09.15           5989
# 5  2016.09.15.R           5988
# 6    2016.09.11           5987
# 7    2016.09.07           5986
# 8    2016.09.06           5985
# 9  2016.09.05.b           5984
#
# [10 rows x 22 columns]

# %%
#Find out where still missing values occur
shark_attacks_copy.isna().sum()[shark_attacks_copy.isna().sum() > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# dtype: int64

# %%
#Sort it and store it in a variable
missing_values_2 = shark_attacks_copy.isna().sum()[shark_attacks_copy.isna().sum() > 0].sort_values(ascending = False)

# %%
missing_values_2
# Out:
# Time                      3213
# Species                   2934
# Age                       2681
# Sex                        567
# Activity                   527
# Location                   496
# Area                       402
# Name                       200
# Country                     43
# Injury                      27
# Fatal (Y/N)                 19
# Investigator or Source      15
# href                         3
# href formula                 1
# dtype: int64

# %%
#Rename column with special characters 

shark_attacks_copy.columns = shark_attacks_copy.columns.str.replace('(','').str.replace(')','').str.replace('/','_')

# %%
#Check new dataframe
shark_attacks_copy.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#   Fatal Y_N   Time   Species        Investigator or Source  \
# 0         N  13h00        NaN  Orlando Sentinel, 9/19/2016
# 1         N  11h00        NaN  Orlando Sentinel, 9/19/2016
# 2         N  10h43        NaN  Orlando Sentinel, 9/19/2016
# 3         N    NaN        NaN           The Age, 9/18/2016
# 4         N    NaN  2 m shark           The Age, 9/16/2016
#
#                          pdf  \
# 0       2016.09.18.c-NSB.pdf
# 1   2016.09.18.b-Luciano.pdf
# 2       2016.09.18.a-NSB.pdf
# 3  2016.09.17-Angiolella.pdf
# 4  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order
# 0  2016.09.18.c           5993
# 1  2016.09.18.b           5992
# 2  2016.09.18.a           5991
# 3    2016.09.17           5990
# 4    2016.09.15           5989
#
# [5 rows x 22 columns]

# %%
#Check types in column time
shark_attacks_copy["Time"]
# Out:
# 0       13h00
# 1       11h00
# 2       10h43
# 3         NaN
# 4         NaN
#         ...
# 5987      NaN
# 5988      NaN
# 5989      NaN
# 5990      NaN
# 5991      NaN
# Name: Time, Length: 5992, dtype: object

# %%
shark_attacks_copy['Time'].dtypes
# Out:
# dtype('O')

# %%
shark_attacks_copy.isna()
# Out:
#       Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0           False  False  False  False    False  False     False     False
# 1           False  False  False  False    False  False     False     False
# 2           False  False  False  False    False  False     False     False
# 3           False  False  False  False    False  False     False     False
# 4           False  False  False  False    False  False     False     False
# ...           ...    ...    ...    ...      ...    ...       ...       ...
# 5987        False  False  False  False    False  False     False     False
# 5988        False  False  False  False    False  False      True     False
# 5989        False  False  False  False    False  False     False     False
# 5990        False  False  False  False    False   True     False      True
# 5991        False  False  False  False    False  False     False     False
#
#        Name   Sex   ...  Fatal Y_N   Time  Species   Investigator or Source  \
# 0     False  False  ...      False  False      True                   False
# 1     False  False  ...      False  False      True                   False
# 2     False  False  ...      False  False      True                   False
# 3     False  False  ...      False   True      True                   False
# 4     False  False  ...      False   True     False                   False
# ...     ...    ...  ...        ...    ...       ...                     ...
# 5987  False  False  ...      False   True      True                   False
# 5988  False  False  ...      False   True      True                   False
# 5989  False  False  ...      False   True      True                   False
# 5990  False  False  ...      False   True      True                   False
# 5991  False  False  ...      False   True      True                   False
#
#         pdf  href formula   href  Case Number.1  Case Number.2  original order
# 0     False         False  False          False          False           False
# 1     False         False  False          False          False           False
# 2     False         False  False          False          False           False
# 3     False         False  False          False          False           False
# 4     False         False  False          False          False           False
# ...     ...           ...    ...            ...            ...             ...
# 5987  False         False  False          False          False           False
# 5988  False         False  False          False          False           False
# 5989  False         False  False          False          False           False
# 5990  False         False  False          False          False           False
# 5991  False         False  False          False          False           False
#
# [5992 rows x 22 columns]

# %%
shark_attacks_copy[shark_attacks_copy["Time"].notnull()]["Time"]
# Out:
# 0                13h00
# 1                11h00
# 2                10h43
# 6                15h15
# 7                14h30
#              ...
# 5931         Afternoon
# 5932         Afternoon
# 5933         Afternoon
# 5949    Late afternoon
# 5955         Afternoon
# Name: Time, Length: 2779, dtype: object

# %%
shark_attacks_copy[shark_attacks_copy["Time"].notnull()]["Time"].replace

# %%
shark_attacks_copy["Time"].isna().count()
# Out:
# 5992

# %%
#Investigate missing values in "Time" column (what to do with Fatal(Y/N)?)
relevant_columns = ["Time", "Date", "Fatal Y_N","Investigator or Source"]
check_time = shark_attacks_copy.loc[shark_attacks_copy["Time"].isna(), relevant_columns].head(30)

check_time.head(30)
# Out:
#    Time                   Date Fatal Y_N             Investigator or Source
# 3   NaN              17-Sep-16         N                 The Age, 9/18/2016
# 4   NaN              16-Sep-16         N                 The Age, 9/16/2016
# 5   NaN              15-Sep-16         N         West Australian, 9/15/2016
# 11  NaN              04-Sep-16         N         Orlando Sentinel, 9/7/2016
# 12  NaN              01-Sep-16         N                   R. Collier, GSAF
# 17  NaN              07-Aug-16         N                     ABC, 8/11/2016
# 18  NaN              06-Aug-16         N                      SUP, 8/9/2015
# 19  NaN              04-Aug-16         N                 News 965, 8/5/2016
# 21  NaN              28-Jul-16         N                Klassick, 7/28/2016
# 22  NaN              28-Jul-16         N           ABC Australia, 7/28/2016
# 23  NaN              27-Jul-16         N         Tampa Bay Times, 7/27/2016
# 26  NaN              23-Jul-16         N                     C. Black, GSAF
# 27  NaN              23-Jul-16         N                    KWTX, 7/23/2016
# 29  NaN              17-Jul-16         N                  Al.com, 7/19/2016
# 32  NaN              15-Jul-16         N                  C. Creswell, GSAF
# 33  NaN  Reported  14-Jul-2016         N                 GrindTV, 7/14/2016
# 34  NaN   Reported 08-Jul-2016         N             La Opinion de Tenerife
# 35  NaN              08-Jul-16         N                   R. Collier, GSAF
# 37  NaN              07-Jul-16         N                   R. Collier, GSAF
# 43  NaN              23-Jun-16         N                 News 24, 6/23/2016
# 47  NaN              15-Jun-16         N               Perth Now, 6/16/2016
# 54  NaN              02-Jun-16       NaN      Gold Coast Bulletin, 6/4/2016
# 70  NaN              18-Apr-16         N            Tahiti Infos, 4/19/2016
# 71  NaN              13-Apr-16         N         Palm Beach Post, 4/13/2016
# 73  NaN              08-Apr-16         N                         L.O.Guttke
# 74  NaN              07-Apr-16         N                                NaN
# 75  NaN              07-Apr-16         N                            YouTube
# 78  NaN              28-Mar-16         N                  Fox 35, 3/30/2015
# 80  NaN              26-Mar-16         N  Wisconsin State Journal, 4/2/2016
# 86  NaN              02-Mar-16         N           Misones Online, 3/4/2016

# %%
#Find out the minimum date
check_time.Date.min()
# Out:
# '01-Sep-16'

# %%
#Find out the maximum date
check_time.Date.max()
# Out:
# 'Reported 08-Jul-2016'

# %%
#Finding 1: Between 01 Sept and 08 Jul 2016 time was not recorded.

# %%
check_time["count"] = 1
check_time.value_counts("Fatal Y_N")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-3a8a9d68f213> in <module>
#       1 check_time["count"] = 1
# ----> 2 check_time.value_counts("Fatal Y_N")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
#Check correlation of dates and time
times_copy = check_time.groupby(['Time'])

# %%
times_copy.head(30)
# Out:
#    Time                   Date Fatal Y_N             Investigator or Source  \
# 3   NaN              17-Sep-16         N                 The Age, 9/18/2016
# 4   NaN              16-Sep-16         N                 The Age, 9/16/2016
# 5   NaN              15-Sep-16         N         West Australian, 9/15/2016
# 11  NaN              04-Sep-16         N         Orlando Sentinel, 9/7/2016
# 12  NaN              01-Sep-16         N                   R. Collier, GSAF
# 17  NaN              07-Aug-16         N                     ABC, 8/11/2016
# 18  NaN              06-Aug-16         N                      SUP, 8/9/2015
# 19  NaN              04-Aug-16         N                 News 965, 8/5/2016
# 21  NaN              28-Jul-16         N                Klassick, 7/28/2016
# 22  NaN              28-Jul-16         N           ABC Australia, 7/28/2016
# 23  NaN              27-Jul-16         N         Tampa Bay Times, 7/27/2016
# 26  NaN              23-Jul-16         N                     C. Black, GSAF
# 27  NaN              23-Jul-16         N                    KWTX, 7/23/2016
# 29  NaN              17-Jul-16         N                  Al.com, 7/19/2016
# 32  NaN              15-Jul-16         N                  C. Creswell, GSAF
# 33  NaN  Reported  14-Jul-2016         N                 GrindTV, 7/14/2016
# 34  NaN   Reported 08-Jul-2016         N             La Opinion de Tenerife
# 35  NaN              08-Jul-16         N                   R. Collier, GSAF
# 37  NaN              07-Jul-16         N                   R. Collier, GSAF
# 43  NaN              23-Jun-16         N                 News 24, 6/23/2016
# 47  NaN              15-Jun-16         N               Perth Now, 6/16/2016
# 54  NaN              02-Jun-16       NaN      Gold Coast Bulletin, 6/4/2016
# 70  NaN              18-Apr-16         N            Tahiti Infos, 4/19/2016
# 71  NaN              13-Apr-16         N         Palm Beach Post, 4/13/2016
# 73  NaN              08-Apr-16         N                         L.O.Guttke
# 74  NaN              07-Apr-16         N                                NaN
# 75  NaN              07-Apr-16         N                            YouTube
# 78  NaN              28-Mar-16         N                  Fox 35, 3/30/2015
# 80  NaN              26-Mar-16         N  Wisconsin State Journal, 4/2/2016
# 86  NaN              02-Mar-16         N           Misones Online, 3/4/2016
#
#     count
# 3       1
# 4       1
# 5       1
# 11      1
# 12      1
# 17      1
# 18      1
# 19      1
# 21      1
# 22      1
# 23      1
# 26      1
# 27      1
# 29      1
# 32      1
# 33      1
# 34      1
# 35      1
# 37      1
# 43      1
# 47      1
# 54      1
# 70      1
# 71      1
# 73      1
# 74      1
# 75      1
# 78      1
# 80      1
# 86      1

# %%
times_copy.count()
# Out:
# Empty DataFrame
# Columns: [Date, Fatal Y_N, Investigator or Source, count]
# Index: []
